# %% [markdown]
# # Exercise 1:

# %% [markdown]
# * When inspecting the hydrogen energy level diagram and comparing with the Harvard spectral sequence, the Balmer $\beta$ is the only visible line in the spectrogram. Each of the different series share their respective lower leves and each series may share an upper level, for instance the $\infty$ level.
#
# * If the temperature is just right, the probability of excitation is greater when the number of atoms sharing the same ground level is high. This may be the idea behind Payne's assumption that the strength of the absorption lines observed in stellar spectra scales with the population density of the lower level of the corresponding transition.
#
# * If we assume that the number of atoms is greatest in the ground state, and that the number of atoms will gradually decrease with the higher levels, then the ratio between Lyman $\alpha$ and Balmer $\alpha$ is greater than the ratio between Lyman $\alpha$ and Paschen $\alpha$, which then again is greater than the ratio between Lyman $\alpha$ and Brackett $\alpha$. The following is true for the Balmer $\alpha$, Paschen $\alpha$ and Brackett $\alpha$ - the ratio between the levels will increase as we look at series with higher lower levels. Overall, the greatest ratio is between Lymann $\alpha$ and Brackett $\alpha$ and the smallest is between Paschen $\alpha$ and Brackett $\alpha$.
#
# * The Saha and Boltzmann distributions behave differently for increasing temperature because the Boltzmann distribution has an T dependency only in the exponential while the Saha distribution, in addition to the T dependency in the exponential, is also dependent on T as a factor. Both the exponential is propotional to $e^{-1/T}$ which imply that this quantity goes to 1 as $T$ gets really high. We notice then that the Boltzmann distribution converge to a value while the Saha distribution diverge.
#
# * From the equations we observe that the Saha ratio goes to infinity when T goes to infinity, while the Boltzmann ratio converge towards a number. This is a result of why ionisation can fully deplete a stage while excitation puts only a few atoms in levels just below the ionisation level.

# %% [markdown]
# # Exercise 2:

# %%
# %matplotlib inline

import numpy
from astropy import units
from astropy import constants
from astropy.visualization import quantity_support
import matplotlib.pyplot as plt


class Atom:
    """
    Reads atomic data, calculates level populations according to Boltzmann's law,
    and ionisation fractions according to Saha's law.
    """
    
    def __init__(self, atomfile=None):
        """
        Parameters
        ----------
        atomfile : string, optional
            Name of file with atomic data. If not present, atomic data needs
            to be loaded with the .read_atom method.
        """
        self.loaded = False
        if atomfile:
            self.read_atom(atomfile)
        
    def read_atom(self, filename):
        """
        Reads atom structure from text file.
        
        Parameters
        ----------
        filename: string
            Name of file with atomic data.
        """
        tmp = numpy.loadtxt(filename, unpack=True)
        self.n_stages = int(tmp[2].max()) + 1
        # Get maximum number of levels in any stage
        self.max_levels = 0
        for i in range(self.n_stages):
            self.max_levels = max(self.max_levels, (tmp[2] == i).sum())
        # Populate level energies and statistical weights
        # Use a square array filled with NaNs for non-existing levels
        chi = numpy.empty((self.n_stages, self.max_levels))
        chi.fill(numpy.nan)
        self.g = numpy.copy(chi)
        for i in range(self.n_stages):
            nlevels = (tmp[2] == i).sum()
            chi[i, :nlevels] = tmp[0][tmp[2] == i]
            self.g[i, :nlevels] = tmp[1][tmp[2] == i]
        # Put units, convert from cm-1 to Joule
        chi = (chi / units.cm).to('aJ', equivalencies=units.spectral())
        # Save ionisation energies, saved as energy of first level in each stage
        self.chi_ion = chi[:, 0].copy()
        # Save level energies relative to ground level in each stage
        self.chi = chi - self.chi_ion[:, numpy.newaxis]
        self.loaded = True
        
    def compute_partition_function(self, temperature):
        if not self.loaded:
            raise ValueError("Missing atom structure, please load atom with read_atom()")
        temp = temperature[numpy.newaxis, numpy.newaxis]
        return numpy.nansum(self.g[...,numpy.newaxis] * numpy.exp(-self.chi[...,numpy.newaxis]/ constants.k_B/temp),axis=1) #newaxis adds a dimension.
    
    def compute_excitation(self, temperature):
        pfunc = self.compute_partition_function(temperature) #partition func
        # Reshape the arrays
        temp = temperature[numpy.newaxis, numpy.newaxis]
        g_ratio = self.g[...,numpy.newaxis] / pfunc[:,numpy.newaxis]
        chi = self.chi[...,numpy.newaxis]
        return g_ratio * numpy.exp(-chi / (constants.k_B * temp))
    
    def compute_ionisation(self, temperature, electron_pressure):
        partition_function = self.compute_partition_function(temperature)
        electron_density = electron_pressure / (constants.k_B * temperature)
        saha_const = ((2*numpy.pi * constants.m_e * constants.k_B * temperature)/(constants.h**2))**(3/2)
        nstage = numpy.zeros_like(partition_function) / units.m **3
        nstage[0] = 1. / units.m**3
        
        for r in range(self.n_stages - 1):
            nstage[r+1] = (nstage[r] / electron_density * 2 * saha_const * \
                         partition_function[r+1] / partition_function[r] * \
                         numpy.exp(-self.chi_ion[r+1, numpy.newaxis] / (constants.k_B * temperature[numpy.newaxis]))) 
            
        return nstage / numpy.nansum(nstage,axis=0)
    
    def compute_population(self,temperature, electron_pressure):
        
        return (self.compute_excitation(temperature)*self.compute_ionisation(temperature, electron_pressure)[:,numpy.newaxis])
    
    def plot_payne(self,temperature, electron_pressure):
        pops = self.compute_population(temperature, electron_pressure)
        fig,ax = plt.subplots()
        ax.plot(numpy.tile(temp, (self.n_stages,1)).T, pops[:,0].T, 'b-')
        n_levels = self.chi.shape[1]
        if n_levels > 1:
            ax.plot(numpy.tile(temp, (self.n_stages, 1)).T, pops[:,1].T, 'r--')
        if n_levels > 2:
            ax.plot(numpy.tile(temp, (self.n_stages, 1)).T, pops[:,2].T, 'k:')
            
        ax.set_yscale('log')
        ax.set_ylim(1e-4, 1.1)
        ax.set_xlabel("Temperature(K)")
        ax.set_ylabel("Populations")

# %% [markdown]
# Now that we have the code ready, we compute the partition function $U_r$ for T = 5000, 10000 and 20000 K, for Ca:

# %%
new_atom = Atom("Ca_atom.txt")
new_atom.compute_partition_function(5000.0 * units.K)  #partition func for 5000 K
# Out:
# <Quantity [[1.16887507],
#            [2.19889057],
#            [1.        ],
#            [4.81535504],
#            [6.91357026],
#            [2.        ]]>

# %%
new_atom.compute_partition_function(10000.0 * units.K) #partition func for 10000 K
# Out:
# <Quantity [[3.45978297],
#            [3.55231088],
#            [1.        ],
#            [5.27699259],
#            [8.08152705],
#            [2.        ]]>

# %%
new_atom.compute_partition_function(20000.0 * units.K) #partition func for 20000 K
# Out:
# <Quantity [[13.62724264],
#            [ 6.70523086],
#            [ 1.00001079],
#            [ 5.5981684 ],
#            [ 9.64653685],
#            [ 2.        ]]>

# %% [markdown]
# The partition function for each stage increases with the temperature, which is what we expect when looking at the expression for $U_r$, and also observed from the prints above.

# %% [markdown]
# Next, we plot the Payne curve for the simplified Ca atom using the same temperature range (100 - 175.000 K) and electron pressure (100 Pa):

# %%
my_atom = Atom("Ca_atom.txt")
temp = numpy.linspace(100,175000,500) * units.K

e_press = 100 * units.Pa
my_atom.plot_payne(temp,e_press)
plt.grid()

# %% [markdown]
# We also plot the Payne curve for the simplified He atom using the same temperature range (100 - 175.000 K) and electron pressure (100 Pa):

# %%
my_atom = Atom("He_atom.txt")
temp = numpy.linspace(100,175000,500) * units.K

e_press = 100 * units.Pa
my_atom.plot_payne(temp,e_press)
plt.grid()

# %% [markdown]
# When comparing the Payne curves for the Ca atom and the He atom within the given temperature interval, we observe that the Ca atom has 6 ionisation stages as opposed to the He atom which has only three stages. We also notice that the first ionization of the He atom occurs at approximately 15 000 K and the first ionization of Ca happens at approximately 3 000 K.

# %% [markdown]
# # Exercise 3

# %% [markdown]
# * In order to see H$\alpha$ an electron needs to drop from the second to the first excited state, and in order to observe Ca$^+$K, an electron has to drop from the first excited state to the ground state. The reason for observing that the strengt of the Ca⁺K line is much greater than the H line, is because most of the electrons in Hydrogen for T $\approx$ 4000-6000 is in the ground state, while Calcium in this temperature interval has excited electrons.
#
#
# Next, we want to compute the strength ratio of these two lines as function of temperature:

# %%
temp = numpy.linspace(1000,20000,100)*units.K
e_press = 10 * units.Pa

h_atom = Atom("H_atom.txt")
ca_atom = Atom("Ca_atom.txt")
h_pops = h_atom.compute_population(temp,e_press)
ca_pops = ca_atom.compute_population(temp,e_press)

ca_abund = 2e-6

ca_h_ratio = ca_pops[1,0] / h_pops[0,1] * ca_abund

fig,ax = plt.subplots()
ax.plot(temp, ca_h_ratio)
ax.set_yscale("log")
ax.set_xlabel("Temperature (K)")
ax.set_ylabel(r"CA II K / H$\alpha$ strength ratio")

plt.grid()

# %% [markdown]
# In this plot we see what we expected - the ratio between Ca$^+$K and H$\alpha$ is exponentially decreasing with temperature. This indicates that the strength of the Ca$^+$K line at lower temperatures is greater than the strength of the H$\alpha$ line, and at higher temperatures (at approximately 10000 K) the strength of the H$\alpha$ line is greater than the strength of the Ca$^+$K line.

# %% [markdown]
# Next, we want to plot the relative population changes $(\Delta n_\mathrm{Ca} / \Delta T) / n_\mathrm{Ca}$ and $(\Delta n_\mathrm{H} /  \Delta T) / n_\mathrm{H}$ for the lower levels of Ca$^+$K and H$\alpha$, using $\Delta T=$ 1 K:

# %%
temp = numpy.linspace(2000,12000,100)*units.K
e_press = 10 * units.Pa

h_atom = Atom("H_atom.txt")
ca_atom = Atom("Ca_atom.txt")
dT = 1 * units.K

n_ca1 = ca_atom.compute_population(temp, e_press)[1,0]
n_ca2 = ca_atom.compute_population(temp-dT, e_press)[1,0]
diff_ca = (n_ca1 - n_ca2) / (dT*n_ca1)

n_h1 = h_atom.compute_population(temp, e_press)[0,1]
n_h2 = h_atom.compute_population(temp-dT, e_press)[0,1]
diff_h = (n_h1 - n_h2) / (dT*n_h1)

fig,ax = plt.subplots(nrows=2)
ax[0].plot(temp, numpy.abs(diff_h), label=r"H")
ax[0].plot(temp, numpy.abs(diff_ca), label=r"Ca$^+$")
ax[0].legend()
ax[0].set_ylabel(r"$(\Delta n_i / \Delta T) / n_i$")
ax[0].grid()

ax[1].plot(temp, n_h1/n_h1.max(), "--", label=r"H")
ax[1].plot(temp, n_ca1/n_ca1.max(), "--", label=r"Ca$^+$")
#ax[1].set_yscale("log")
ax[1].legend()
ax[1].set_ylabel("Relative populations")
ax[1].set_xlabel("Temperature (K)")
ax[1].grid()

# %% [markdown]
# We observe that the two temperature sensitivity curves in the top plot is starting to accelerate downwards at a temperature around $T \approx$ 4000 K for Ca$^+$ and at around $T \approx$ 9000 K for H$\alpha$, and stops at around $T \approx$ 5600 K for Ca$^+$ and $T \approx$ 9500 K for H$\alpha$.
#
# For $T \approx$ 5600 K the temperature sensitivity of Ca$^+$K is much smaller than the temperature sensitivity of H$\alpha$. In the two population curves in the plot on the bottom, we observe that the relative population sensitivity for Ca$^+$ is increasing at a lower temperature around 3500 K, and that the increase before the top at $T \approx$ 5600 K is steeper than the descreasing area. We also observe that the relative population sensitivity for H$\alpha$ is increasing at a temperature around 6800 K, and reaches its peak at $T \approx$ 9500 K. From $T \approx$ 11000 K to $T \approx$ 12000 K the relative population sensitivity for both Ca$^+$ and H$\alpha$ behaves parallel.
#
# When comparing the two plots, we observe that the curves correspond well with each other, for Ca$^+$ and H$\alpha$ respectively. We assumed earlier that the relative population of Ca$^+$ would increase and be greater than the relative population for H$\alpha$ at lower temperatures, which matches these results.

# %% [markdown]
# Lastly, we find at which temperature the hydrogen in stellar photospheres with $P_e =$ 10 Pa is about 50% ionised, by plotting the neutral and ionised fractions of hydrogen as a function of temperature.

# %%
my_atom = Atom("H_atom.txt")
temp = numpy.linspace(5000,15000,500) * units.K

e_press = 10 * units.Pa
my_atom.plot_payne(temp,e_press)
plt.grid()

# %% [markdown]
# From this plot we observe that the hydrogen is 50% ionised at a temperature around $T \approx 9300 K$, where the two curves representing the neutral and ionised fractions are crossing eachother.
